# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import transforms
from sklearn.model_selection import train_test_split

# Importation de tes modules personnalisés
from src.data_loader import MedReportDataset
from src.model import get_model

# Configuration du matériel (GPU si disponible, sinon CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"L'entraînement se déroulera sur : {device}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#       9 from sklearn.model_selection import train_test_split
#      11 # Importation de tes modules personnalisés
# ---> 12 from src.data_loader import MedReportDataset
#      13 from src.model import get_model
#      15 # Configuration du matériel (GPU si disponible, sinon CPU)
#
# ModuleNotFoundError: No module named 'src'
